# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

import sys
import os

# %% [markdown]
# ##### setup working directory and files

# %%
currDir='2A-L1'
imgsDir=currDir+'/images'

# %% [markdown]
# ##### Codes

# %%
os.listdir(imgs)
# Out:
# ['bicycle.png', 'dolphin.png', 'fruit.png']

# %%
plt.clf()
img=cv2.imread(imgsDir+'/fruit.png', 1)
plt.imshow(img.astype(np.uint8))
plt.show()
print img
# Out:
# [[[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...,
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...,
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...,
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  ...,
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...,
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...,
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...,
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]]

# %%
min(183+152, 255)/2.
# Out:
# 127.5

# %%
31228+16336+3535+547+14200+67000
# Out:
# 132846
